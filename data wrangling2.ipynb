# %%
import pandas as pd

# %%
vari=pd.read_csv('C:\\Users\\ADMIN\\Documents\\Nandhu\\assingment.csv')

# %%
vari
# Out:
#     Unnamed: 0                                     playars name  \
# 0            0         \n            Kashiling Adake\n
# 1            1          \n            Pardeep Narwal\n
# 2            2    \n            Pawan Kumar Sehrawat\n
# 3            3      \n            Deepak Niwas Hooda\n
# 4            4         \n            Rahul Chaudhari\n
# 5            5          \n            Maninder Singh\n
# 6            6          \n            Sandeep Narwal\n
# 7            7        \n            Manjeet Chhillar\n
# 8            8             \n            Ajay Thakur\n
# 9            9            \n            Naveen Kumar\n
# 10          10           \n            Vikas Kandola\n
# 11          11        \n            Rishank Devadiga\n
# 12          12                  \n            Sachin\n
# 13          13        \n            PO Surjeet Singh\n
# 14          14              \n            Anup Kumar\n
# 15          15             \n            Nitin Tomar\n
# ...

# %%
vari.drop("Unnamed: 0",inplace=True,axis=1)

# %%
vari
# Out:
#                                        playars name  \
# 0          \n            Kashiling Adake\n
# 1           \n            Pardeep Narwal\n
# 2     \n            Pawan Kumar Sehrawat\n
# 3       \n            Deepak Niwas Hooda\n
# 4          \n            Rahul Chaudhari\n
# 5           \n            Maninder Singh\n
# 6           \n            Sandeep Narwal\n
# 7         \n            Manjeet Chhillar\n
# 8              \n            Ajay Thakur\n
# 9             \n            Naveen Kumar\n
# 10           \n            Vikas Kandola\n
# 11        \n            Rishank Devadiga\n
# 12                  \n            Sachin\n
# 13        \n            PO Surjeet Singh\n
# 14              \n            Anup Kumar\n
# 15             \n            Nitin Tomar\n
# 16             \n            Rohit Kumar\n
# 17          \n            Ravinder Pahal\n
# 18         \n            Fazel Atrachali\n
# 19         \n            Shrikant Jadhav\n
# ...

# %%
type(vari.loc[0,"playars name"])
# Out:
# str

# %%
vari["playars name"]=vari["playars name"].str.strip('\n \n	')

# %%
vari
# Out:
#               playars name                                           catagery  \
# 0          Kashiling Adake  <div class="players-list-category">\n         ...
# 1           Pardeep Narwal  <div class="players-list-category">\n         ...
# 2     Pawan Kumar Sehrawat  <div class="players-list-category">\n         ...
# 3       Deepak Niwas Hooda  <div class="players-list-category">\n         ...
# 4          Rahul Chaudhari  <div class="players-list-category">\n         ...
# 5           Maninder Singh  <div class="players-list-category">\n         ...
# 6           Sandeep Narwal  <div class="players-list-category">\n         ...
# 7         Manjeet Chhillar  <div class="players-list-category">\n         ...
# 8              Ajay Thakur  <div class="players-list-category">\n         ...
# 9             Naveen Kumar  <div class="players-list-category">\n         ...
# 10           Vikas Kandola  <div class="players-list-category">\n         ...
# ...

# %%
vari["catagery"]=vari["catagery"].str.strip('"<div class="players-list-category"> </div>"')

# %%
vari
# Out:
#               playars name  catagery  \
# 0          Kashiling Adake  All Roun
# 1           Pardeep Narwal         R
# 2     Pawan Kumar Sehrawat  All Roun
# 3       Deepak Niwas Hooda  All Roun
# 4          Rahul Chaudhari  All Roun
# 5           Maninder Singh         R
# 6           Sandeep Narwal  All Roun
# 7         Manjeet Chhillar     Defen
# 8              Ajay Thakur         R
# 9             Naveen Kumar         R
# 10           Vikas Kandola         R
# 11        Rishank Devadiga         R
# 12                  Sachin         R
# 13        PO Surjeet Singh     Defen
# 14              Anup Kumar  All Roun
# 15             Nitin Tomar  All Roun
# 16             Rohit Kumar         R
# 17          Ravinder Pahal     Defen
# 18         Fazel Atrachali     Defen
# 19         Shrikant Jadhav         R
# 20              Monu Goyat         R
# 21            Nitesh Kumar     Defen
# 22       Parvesh Bhainswal     Defen
# 23  Siddharth Sirish Desai         R
# ...

# %%
vari["catagery"]=vari["catagery"].str.strip('\n')

# %%
vari
# Out:
#               playars name              catagery  \
# 0          Kashiling Adake              All Roun
# 1           Pardeep Narwal                     R
# 2     Pawan Kumar Sehrawat              All Roun
# 3       Deepak Niwas Hooda              All Roun
# 4          Rahul Chaudhari              All Roun
# 5           Maninder Singh                     R
# 6           Sandeep Narwal              All Roun
# 7         Manjeet Chhillar                 Defen
# 8              Ajay Thakur                     R
# 9             Naveen Kumar                     R
# 10           Vikas Kandola                     R
# 11        Rishank Devadiga                     R
# 12                  Sachin                     R
# 13        PO Surjeet Singh                 Defen
# 14              Anup Kumar              All Roun
# 15             Nitin Tomar              All Roun
# 16             Rohit Kumar                     R
# 17          Ravinder Pahal                 Defen
# ...
