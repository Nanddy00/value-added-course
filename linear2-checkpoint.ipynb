# %%
import warnings 
warnings.simplefilter('ignore')  #don't come any other warnings

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
ad=pd.read_csv("C:\\Users\\admin\\Downloads\\Admission_predict.csv")

# %%
ad
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
ad.shape
# Out:
# (400, 9)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
ap=ad.drop(['Serial No.','GRE Score','University Rating','SOP','LOR ','CGPA','Research'],axis=1)

# %%
ap
# Out:
#      TOEFL Score  Chance of Admit
# 0            118              0.92
# 1            107              0.76
# 2            104              0.72
# 3            110              0.80
# 4            103              0.65
# ..           ...               ...
# 395          110              0.82
# 396          107              0.84
# 397          116              0.91
# 398          103              0.67
# 399          117              0.95
#
# [400 rows x 2 columns]

# %%
x=ap.iloc[:,0].values.reshape(-1,1)
y=ap.iloc[:,1].values.reshape(-1,1)

# %%
x
# Out:
# array([[118],
#        [107],
#        [104],
#        [110],
#        [103],
#        [115],
#        [109],
#        [101],
#        [102],
#        [108],
#        [106],
#        [111],
#        [112],
#        [109],
#        [104],
#        [105],
#        [107],
#        [106],
#        [110],
#        [102],
#        [107],
#        [114],
#        [116],
#        [119],
#        [119],
#        [120],
#        [109],
#        [ 98],
#        [ 93],
#        [ 99],
#        [ 97],
#        [103],
#        [118],
#        [114],
#        [112],
#        [110],
#        [106],
#        [105],
#        [105],
#        [108],
#        [110],
#        [105],
#        [107],
#        [117],
#        [113],
#        [110],
#        [114],
#        [119],
#        [110],
#        [111],
#        [ 98],
#        [100],
#        [116],
#        [112],
#        [110],
#        [103],
#        [102],
#        [ 99],
#        [ 99],
#        [104],
#        [100],
#        [101],
# ...

# %%
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
plt.scatter(x,y)
plt.xlabel('TOEFL Score')
plt.ylabel('Chance of Admit')
plt.title('linear regression')
plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=0)

# %%
x_train.shape
# Out:
# (280, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
l=LinearRegression()

# %%
l
# Out:
# LinearRegression()

# %%
x_train
# Out:
# array([[ 98],
#        [109],
#        [113],
#        [107],
#        [100],
#        [115],
#        [116],
#        [100],
#        [107],
#        [ 97],
#        [114],
#        [104],
#        [114],
#        [101],
#        [110],
#        [105],
#        [108],
#        [109],
#        [100],
#        [106],
#        [111],
#        [107],
#        [ 97],
#        [105],
#        [111],
#        [104],
#        [105],
#        [110],
#        [111],
#        [102],
#        [113],
#        [117],
#        [109],
#        [107],
#        [116],
#        [103],
#        [110],
#        [113],
#        [104],
#        [112],
#        [110],
#        [112],
#        [114],
#        [ 98],
#        [109],
#        [112],
#        [106],
#        [120],
#        [103],
#        [101],
#        [102],
#        [106],
#        [103],
#        [106],
#        [104],
#        [114],
#        [116],
#        [114],
#        [106],
#        [107],
#        [105],
#        [108],
# ...

# %%
x_train.shape
# Out:
# (280, 1)

# %%
y_train
# Out:
# array([[0.34],
#        [0.71],
#        [0.91],
#        [0.69],
#        [0.47],
#        [0.92],
#        [0.94],
#        [0.71],
#        [0.74],
#        [0.64],
#        [0.93],
#        [0.77],
#        [0.61],
#        [0.6 ],
#        [0.84],
#        [0.64],
#        [0.84],
#        [0.77],
#        [0.63],
#        [0.65],
#        [0.81],
#        [0.84],
#        [0.65],
#        [0.59],
#        [0.7 ],
#        [0.57],
#        [0.7 ],
#        [0.81],
#        [0.88],
#        [0.56],
#        [0.8 ],
#        [0.94],
#        [0.79],
#        [0.62],
#        [0.93],
#        [0.76],
#        [0.78],
#        [0.85],
#        [0.7 ],
#        [0.71],
#        [0.8 ],
#        [0.79],
#        [0.9 ],
#        [0.56],
#        [0.67],
#        [0.94],
#        [0.74],
#        [0.86],
#        [0.76],
#        [0.47],
#        [0.64],
#        [0.81],
#        [0.73],
#        [0.71],
#        [0.73],
#        [0.89],
#        [0.93],
#        [0.86],
# ...

# %%
l.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=l.predict(x_test)

# %%
y_predict
# Out:
# array([[0.68052335],
#        [0.77518402],
#        [0.77518402],
#        [0.68052335],
#        [0.68052335],
#        [0.58586269],
#        [0.75625188],
#        [0.66159122],
#        [0.92664107],
#        [0.90770894],
#        [0.68052335],
#        [0.83198041],
#        [0.77518402],
#        [0.56693056],
#        [0.81304828],
#        [0.66159122],
#        [0.54799843],
#        [0.77518402],
#        [0.56693056],
#        [0.71838762],
#        [0.94557321],
#        [0.83198041],
#        [0.69945549],
#        [0.51013416],
#        [0.79411615],
#        [0.58586269],
#        [0.49120203],
#        [0.68052335],
#        [0.92664107],
#        [0.69945549],
#        [0.60479483],
#        [0.71838762],
#        [0.71838762],
#        [0.56693056],
#        [0.81304828],
#        [0.81304828],
#        [0.69945549],
#        [0.83198041],
#        [0.62372696],
#        [0.90770894],
#        [0.71838762],
#        [0.71838762],
#        [0.75625188],
# ...

# %%
cp=pd.DataFrame(x_test,columns=['gre'])

# %%
cp
# Out:
#      gre
# 0    105
# 1    110
# 2    110
# 3    105
# 4    105
# ..   ...
# 115  112
# 116  119
# 117  111
# 118  104
# 119  103
#
# [120 rows x 1 columns]

# %%
cp['AVLDATA']=y_test

# %%
cp
# Out:
#      gre  AVLDATA
# 0    105     0.71
# 1    110     0.70
# 2    110     0.79
# 3    105     0.73
# 4    105     0.72
# ..   ...      ...
# 115  112     0.91
# 116  119     0.90
# 117  111     0.78
# 118  104     0.70
# 119  103     0.59
#
# [120 rows x 2 columns]

# %%
cp['PRDDATA']=y_predict

# %%
cp
# Out:
#      gre  AVLDATA   PRDDATA
# 0    105     0.71  0.680523
# 1    110     0.70  0.775184
# 2    110     0.79  0.775184
# 3    105     0.73  0.680523
# 4    105     0.72  0.680523
# ..   ...      ...       ...
# 115  112     0.91  0.813048
# 116  119     0.90  0.945573
# 117  111     0.78  0.794116
# 118  104     0.70  0.661591
# 119  103     0.59  0.642659
#
# [120 rows x 3 columns]

# %%
plt.scatter(x,y,color='red')
plt.plot(x_test,y_predict,color='blue')
plt.xlabel('TOEFL Score')
plt.ylabel('cha')
plt.title('linear reg')
plt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 0.007141114056133616

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 0.06396164474243281
