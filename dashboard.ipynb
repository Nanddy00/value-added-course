# %%
import seaborn as sb

# %%
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
dms=sb.load_dataset('diamonds')

# %%
dms
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
dms.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.bar(dms['cut'],dms['table'])
# Out:
# <BarContainer object of 53940 artists>

# %%
sb.relplot(x='carat',y='depth',data=dms,col='depth',hue="clarity",style="depth",kind="line") #line or scatter
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 sb.relplot(x='carat',y='depth',data=dms,col='depth',hue="clarity",style="depth",kind="line")
#
# File ~\anaconda3\envs\nandhu\lib\site-packages\seaborn\relational.py:946, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     944 # Set up the FacetGrid object
#     945 facet_kws = {} if facet_kws is None else facet_kws.copy()
# --> 946 g = FacetGrid(
#     947     data=full_data.dropna(axis=1, how="all"),
#     948     **grid_kws,
#     949     col_wrap=col_wrap, row_order=row_order, col_order=col_order,
#     950     height=height, aspect=aspect, dropna=False,
#     951     **facet_kws
#     952 )
# ...

# %%
sb.catplot(x='carat',y='depth',kind='box',data=dms)

# %%
plt.plot(dms['x'],dms['y'],linestyle='dotted')

# %%
sb.regplot(x=dms['cut'],y=dms['depth'],data=dms)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 sb.regplot(x=dms['cut'],y=dms['depth'],data=dms)
#
# File ~\anaconda3\envs\nandhu\lib\site-packages\seaborn\regression.py:747, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     736 def regplot(
#     737     data=None, *, x=None, y=None,
#     738     x_estimator=None, x_bins=None, x_ci="ci",
#    (...)
#     744     scatter_kws=None, line_kws=None, ax=None
#     745 ):
# --> 747     plotter = _RegressionPlotter(x, y, data, x_estimator, x_bins, x_ci,
#     748                                  scatter, fit_reg, ci, n_boot, units, seed,
# ...
