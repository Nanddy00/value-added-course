# %%
import pandas as pd

# %%
var=pd.read_csv("C:\\Users\\ADMIN\Documents\\Nandhu\\webscraping.csv")

# %%
var.drop("Unnamed: 0",inplace=True,axis=1)

# %%
var
# Out:
#                                           movie title  \
# 0                            The Shawshank Redemption
# 1                                       The Godfather
# 2                                     The Dark Knight
# 3                               The Godfather Part II
# 4                                    Schindler's List
# 5       The Lord of the Rings: The Return of the King
# 6                                        12 Angry Men
# 7                                        Pulp Fiction
# 8   The Lord of the Rings: The Fellowship of the Ring
# 9                                           Inception
# 10                                         Fight Club
# 11                                       Forrest Gump
# 12              The Lord of the Rings: The Two Towers
# 13                    Il buono, il brutto, il cattivo
# 14                                           Jai Bhim
# 15                                         GoodFellas
# ...

# %%
type(var.loc[0,"movie title"])
# Out:
# str

# %%
var["year"]=var["year"].str.strip('<span class="lister-item-year text-muted unbold">()</span>')

# %%
var
# Out:
#                                           movie title  \
# 0                            The Shawshank Redemption
# 1                                       The Godfather
# 2                                     The Dark Knight
# 3                               The Godfather Part II
# 4                                    Schindler's List
# 5       The Lord of the Rings: The Return of the King
# 6                                        12 Angry Men
# 7                                        Pulp Fiction
# 8   The Lord of the Rings: The Fellowship of the Ring
# 9                                           Inception
# 10                                         Fight Club
# 11                                       Forrest Gump
# 12              The Lord of the Rings: The Two Towers
# 13                    Il buono, il brutto, il cattivo
# 14                                           Jai Bhim
# 15                                         GoodFellas
# ...

# %%
var["duration"]=var["duration"].str.strip('<span class="runtime"> min</span>')

# %%
var
# Out:
#                                           movie title  \
# 0                            The Shawshank Redemption
# 1                                       The Godfather
# 2                                     The Dark Knight
# 3                               The Godfather Part II
# 4                                    Schindler's List
# 5       The Lord of the Rings: The Return of the King
# 6                                        12 Angry Men
# 7                                        Pulp Fiction
# 8   The Lord of the Rings: The Fellowship of the Ring
# 9                                           Inception
# 10                                         Fight Club
# 11                                       Forrest Gump
# 12              The Lord of the Rings: The Two Towers
# 13                    Il buono, il brutto, il cattivo
# 14                                           Jai Bhim
# 15                                         GoodFellas
# ...

# %%
var["movietypes"]=var["movietypes"].str.strip('<span class="genre"></span>')

# %%
var
# Out:
#                                           movie title  \
# 0                            The Shawshank Redemption
# 1                                       The Godfather
# 2                                     The Dark Knight
# 3                               The Godfather Part II
# 4                                    Schindler's List
# 5       The Lord of the Rings: The Return of the King
# 6                                        12 Angry Men
# 7                                        Pulp Fiction
# 8   The Lord of the Rings: The Fellowship of the Ring
# 9                                           Inception
# 10                                         Fight Club
# 11                                       Forrest Gump
# 12              The Lord of the Rings: The Two Towers
# 13                    Il buono, il brutto, il cattivo
# 14                                           Jai Bhim
# 15                                         GoodFellas
# ...

# %%
var["movietypes"]=var["movietypes"].str.strip('\n')

# %%
var
# Out:
#                                           movie title  \
# 0                            The Shawshank Redemption
# 1                                       The Godfather
# 2                                     The Dark Knight
# 3                               The Godfather Part II
# 4                                    Schindler's List
# 5       The Lord of the Rings: The Return of the King
# 6                                        12 Angry Men
# 7                                        Pulp Fiction
# 8   The Lord of the Rings: The Fellowship of the Ring
# 9                                           Inception
# 10                                         Fight Club
# 11                                       Forrest Gump
# 12              The Lord of the Rings: The Two Towers
# 13                    Il buono, il brutto, il cattivo
# 14                                           Jai Bhim
# 15                                         GoodFellas
# ...

# %%
var.drop("rating",inplace=True,axis=1)

# %%
var
# Out:
#                                           movie title  year  \
# 0                            The Shawshank Redemption  1994
# 1                                       The Godfather  1972
# 2                                     The Dark Knight  2008
# 3                               The Godfather Part II  1974
# 4                                    Schindler's List  1993
# 5       The Lord of the Rings: The Return of the King  2003
# 6                                        12 Angry Men  1957
# 7                                        Pulp Fiction  1994
# 8   The Lord of the Rings: The Fellowship of the Ring  2001
# 9                                           Inception  2010
# 10                                         Fight Club  1999
# 11                                       Forrest Gump  1994
# 12              The Lord of the Rings: The Two Towers  2002
# 13                    Il buono, il brutto, il cattivo  1966
# 14                                           Jai Bhim  2021
# ...

# %%
var.to_csv('C:\\Users\\ADMIN\\Documents\\Nandhu\\datawrangling.csv')
